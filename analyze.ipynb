# %%
import numpy as np
import pandas as pd
from genderize import Genderize

# %%
df = pd.read_csv("Bounce-Guests-2.csv", encoding='latin-1')
df["Date"] = pd.to_datetime(df["Date"])
df
# Out:
#     ï»¿Last Name First Name  Scanned        txn  Amount_Paid  \
# 0        kuchhal    nandini    False  completed            5
# 1         Pandey      Mitul    False  completed           10
# 2       Raveshia     Mishti    False  completed            5
# 3         Kapoor     Madhav    False  completed            5
# 4        gambhir      ameek    False  completed            5
# ..           ...        ...      ...        ...          ...
# 323       verma       arav     False  completed           20
# 324        Dhruv      Dhruv    False  completed           20
# 325          NaN        Sum    False  completed           20
# 326     Sarawagi       Aman    False  completed           20
# 327           Hu    Vanessa    False  completed            5
#
#            Price_Tier  Unknown                Date
# 0                 VIP      NaN 2021-10-18 19:27:19
# 1                 NaN      NaN 2021-10-17 21:29:54
# 2    EARLY BIRD PRICE      NaN 2021-10-17 02:27:17
# ...

# %%
ticketsSold = {}
ticketsSold["5"] = df.query("Amount_Paid == 5").shape[0]
ticketsSold["15"] = df.query("Amount_Paid == 15").shape[0]
ticketsSold["20"] = df.query("Amount_Paid == 20").shape[0]

print(ticketsSold)
# Out:
# {'5': 120, '15': 82, '20': 59}

# %%
sorted_df = df.sort_values(by="Date")
sorted_df
# Out:
#     ï»¿Last Name First Name  Scanned        txn  Amount_Paid  \
# 119       Ralhan      Aanya    False  completed            5
# 118       Bhasin     Khushi    False  completed            5
# 120          Wei    Kathryn    False  completed            5
# 117       Sharma    Akshita    False  completed            5
# 115            s      pavit    False  completed            5
# ..           ...        ...      ...        ...          ...
# 326     Sarawagi       Aman    False  completed           20
# 322      Simonot   Veronica    False  completed           20
# 225        Gupta     Ananya    False  completed            5
# 327           Hu    Vanessa    False  completed            5
# 42      Sachdeva    Muskaan    False  completed            5
#
#            Price_Tier  Unknown                Date
# 119               NaN      NaN 2021-10-15 20:22:36
# 118               NaN      NaN 2021-10-15 20:24:51
# 120  EARLY BIRD PRICE      NaN 2021-10-15 22:32:55
# ...

# %%
sorted_df_subset = sorted_df.query("Amount_Paid == 20")
#sorted_df_subset = sorted_df.sort_values(by="Date")
sorted_df_subset["Time_Between"] = sorted_df_subset["Date"] - sorted_df_subset["Date"].shift(1)

inter_time = sorted_df_subset["Time_Between"].mean()

rate_per_hour = np.timedelta64(1, 'h')/inter_time

print("Rate per hour: %.3f" % rate_per_hour)

sorted_df_subset
# Out:
# Rate per hour: 2.661
# C:\Users\Ben\AppData\Local\Programs\Python\Python36-32\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     ï»¿Last Name     First Name  Scanned        txn  Amount_Paid Price_Tier  \
# 151       craven        michael    False  completed           20        NaN
# 47       Serrano          Sofia    False  completed           20        NaN
# 280          Kim          Henry    False  completed           20        NaN
# 285  Tan Palanca            Kim    False  completed           20        NaN
# 286       Thomas         Makena    False  completed           20        NaN
# ...

# %%
3.481*11*24
# Out:
# 918.9839999999999

# %%
names = list(sorted_df["First Name"])

predictions = []
import gender_guesser.detector as gender
d = gender.Detector()
for name in names:
  predictions.append(d.get_gender(name))

#results = Genderize().get(names)
#predictions = [entry["gender"] for entry in results]

#sorted_df["Gender"] = predictions

print("Males:", predictions.count("male") + predictions.count("mostly_male"))
print("Females:", predictions.count("female") + predictions.count("mostly_female"))
print("Unknown:", predictions.count("unknown"))
# Out:
# Males: 65
# Females: 88
# Unknown: 174

# %%
print(predictions)
# Out:
# ['unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'male', 'male', 'male', 'male', 'andy', 'male', 'male', 'unknown', 'female', 'female', 'male', 'female', 'unknown', 'unknown', 'female', 'mostly_female', 'female', 'male', 'unknown', 'unknown', 'female', 'male', 'female', 'unknown', 'unknown', 'female', 'male', 'unknown', 'female', 'female', 'female', 'female', 'unknown', 'female', 'male', 'male', 'unknown', 'female', 'female', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'male', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'male', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'mostly_female', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'female', 'unknown', 'unknown', 'unknown', 'unknown', 'male', 'unknown', 'female', 'mostly_female', 'male', 'unknown', 'male', 'unknown', 'unknown', 'unkn
# ...
